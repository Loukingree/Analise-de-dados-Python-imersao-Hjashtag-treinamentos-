# %% [markdown]
# # Python Insights - Analisando Dados com Python
#
# ### Case - Cancelamento de Clientes
#
# Você foi contratado por uma empresa com mais de 800 mil clientes para um projeto de Dados. Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
# Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.
#
# Base de dados e arquivos: https://drive.google.com/drive/folders/1uDesZePdkhiraJmiyeZ-w5tfc8XsNYFZ?usp=drive_link

# %%
# Passo 1 - Importar base de dados
# Passo 2 - visualizar a base de dados, quais informacoes ela tem, quais problemas resolver
# Passo 3 - Corrigir as cagadas da base de dados COLUNAS INUTEIS, VALORES VAZIOS, INFORMACOES QUE NAO TE AJUDAM TE ATRAPALHAM!
# Passo 4 - analise inicial dos cancelamentos, quantos cliente cancelaram etc
# Passo 5 - analise das causas do cancelamentos GRAFICOS

#import pyautogui as gui (apelido)
import pandas as pd

tabela = pd.read_csv("cancelamentos.csv")
tabela = tabela.drop(columns = "CustomerID")      # columns/index = ["CustomerID", "idade"]  lista de colunas ou linhas a retirar

#print(tabela.info())
tabela = tabela.dropna() #tabela.fillna()
display(tabela)                                   #print(tabela) ou gui.write(tabela)
print(tabela.info())                              # float -> numero decimal, object/string -> textos, int -> inteiros
# Out:
#         idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        30.0  Female                39.0            14.0
# 1        65.0  Female                49.0             1.0
# 2        55.0  Female                14.0             4.0
# 3        58.0    Male                38.0            21.0
# 4        23.0    Male                32.0            20.0
# ...       ...     ...                 ...             ...
# 881661   42.0    Male                54.0            15.0
# 881662   25.0  Female                 8.0            13.0
# 881663   26.0    Male                35.0            27.0
# 881664   28.0    Male                55.0            14.0
# 881665   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 0                       5.0         18.0   Standard           Annual
# 1                      10.0          8.0      Basic          Monthly
# ...

# %%
#TOTAL CANCELAMENTOS
display(tabela["cancelou"].value_counts())
display(tabela["cancelou"].value_counts(normalize=True).map("{:.1%}".format)) #.map("{:.1%}".format) ou *100

    #Clear Cell outputs 

    #Eliminar a assinatura mensal:
#tabela = tabela[tabela["duracao_contrato"]!="Monthly"] # filtrar/condicao = ["duracao_contrato"]!="Monthly"

    #Reduzir para, no maximo, 3 ligacoes para callcenter: - 20% cancelamentos!
#tabela = tabela[tabela["ligacoes_callcenter"]<=4]

    #Eliminar os dias de atraso:
#tabela = tabela[tabela["dias_atraso"]<=20]
# Out:
# cancelou
# 1.0    499993
# 0.0    381666
# Name: count, dtype: int64
# cancelou
# 1.0    56.7%
# 0.0    43.3%
# Name: proportion, dtype: object

# %%
# Passo 5 analise de causas dos cancelamentos/ graficos dashboards
# !pip install plotly (PLOTLY Python)
import plotly.express as px

# 1 criar o grafico
for coluna in tabela.columns:                                  # coluna = "duracao_contrato"
    grafico = px.histogram(tabela, x=coluna, color="cancelou") # ,color_discrete_map= 
    # 2 exibir o grafico
    grafico.show()

# Primeiro problema: clientes do contrato MENSAL todos cancelaram!
    # oferecer desconto nos planos anuais e trimestrais
# A partir dos 51 anos todos cancelaram!
# As mulheres cancelam mais
# Quanto menos ligacoes de call center menos cancelam, se o cliente precisar ligar mais que 4 vezes no call center cancelaram!
    # criar um processo para resolver o problema do cliente em, no maximo, 3 ligacoes.
# Mais de 20 dias de atraso todos cancelaram!
    # Politica de resolver atrasos em ate 10 dias.
# Dentre os que gastam 500 ou menos todos cancelaram!
# A partir de 16 meses sem interacao a taxa de cancelamento sobe 50%!
